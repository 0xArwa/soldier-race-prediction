# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# In this project, you must apply EDA processes for the development of predictive models. Handling outliers, domain knowledge and feature engineering will be challenges.
#
# Also, this project aims to improve your ability to implement algorithms for Multi-Class Classification. Thus, you will have the opportunity to implement many algorithms commonly used for Multi-Class Classification problems.
#
# Before diving into the project, please take a look at the determines and tasks.

# %% [markdown]
# # Determines

# %% [markdown]
# The 2012 US Army Anthropometric Survey (ANSUR II) was executed by the Natick Soldier Research, Development and Engineering Center (NSRDEC) from October 2010 to April 2012 and is comprised of personnel representing the total US Army force to include the US Army Active Duty, Reserves, and National Guard. In addition to the anthropometric and demographic data described below, the ANSUR II database also consists of 3D whole body, foot, and head scans of Soldier participants. These 3D data are not publicly available out of respect for the privacy of ANSUR II participants. The data from this survey are used for a wide range of equipment design, sizing, and tariffing applications within the military and has many potential commercial, industrial, and academic applications.
#
# The ANSUR II working databases contain 93 anthropometric measurements which were directly measured, and 15 demographic/administrative variables explained below. The ANSUR II Male working database contains a total sample of 4,082 subjects. The ANSUR II Female working database contains a total sample of 1,986 subjects.
#
#
# DATA DICT:
# https://data.world/datamil/ansur-ii-data-dictionary/workspace/file?filename=ANSUR+II+Databases+Overview.pdf
#
# ---
#
# To achieve high prediction success, you must understand the data well and develop different approaches that can affect the dependent variable.
#
# Firstly, try to understand the dataset column by column using pandas module. Do research within the scope of domain (body scales, and race characteristics) knowledge on the internet to get to know the data set in the fastest way.
#
# You will implement ***Logistic Regression, Support Vector Machine, XGBoost, Random Forest*** algorithms. Also, evaluate the success of your models with appropriate performance metrics.
#
# At the end of the project, choose the most successful model and try to enhance the scores with ***SMOTE*** make it ready to deploy. Furthermore, use ***SHAP*** to explain how the best model you choose works.

# %% [markdown]
# # Tasks

# %% [markdown]
# #### 1. Exploratory Data Analysis (EDA)
# - Import Libraries, Load Dataset, Exploring Data
#
#     *i. Import Libraries*
#
#     *ii. Ingest Data *
#
#     *iii. Explore Data*
#
#     *iv. Outlier Detection*
#
#     *v.  Drop unnecessary features*
#
# #### 2. Data Preprocessing
# - Scale (if needed)
# - Separete the data frame for evaluation purposes
#
# #### 3. Multi-class Classification
# - Import libraries
# - Implement SVM Classifer
# - Implement Decision Tree Classifier
# - Implement Random Forest Classifer
# - Implement XGBoost Classifer
# - Compare The Models

# %% [markdown]
# # EDA
# - Drop unnecessary colums
# - Drop DODRace class if value count below 500 (we assume that our data model can't learn if it is below 500)

# %% [markdown]
# ## Import Libraries
# Besides Numpy and Pandas, you need to import the necessary modules for data visualization, data preprocessing, Model building and tuning.
#
# *Note: Check out the course materials.*

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LogisticRegression
from pprint import pprint 
from sklearn.preprocessing import TargetEncoder
from sklearn.model_selection import train_test_split
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import cross_validate, cross_val_score, GridSearchCV
from sklearn.svm import SVC
import warnings
warnings.filterwarnings('ignore') 
sns.set_style('whitegrid')
pd.set_option('display.max_rows', None)

# %matplotlib inline

# %% [markdown]
# ## Ingest Data from links below and make a dataframe
# - Soldiers Male : https://query.data.world/s/h3pbhckz5ck4rc7qmt2wlknlnn7esr
# - Soldiers Female : https://query.data.world/s/sq27zz4hawg32yfxksqwijxmpwmynq

# %%
df1 = pd.read_csv('ANSUR II MALE Public.csv', encoding = 'Latin-1')

# %%
df2 = pd.read_csv('ANSUR II FEMALE Public.csv', encoding = 'Latin-1')

# %%
# check if they have the same columns
set(df1.columns) == set(df2.columns)
# Out:
# False

# %%
# print uncommon items
set(df1.columns) ^ (set(df2.columns))
# Out:
# {'SubjectId', 'subjectid'}

# %%
df1.rename(columns={'subjectid': 'SubjectId'}, inplace=True)

# %%
set(df1.columns) == set(df2.columns)
# Out:
# True

# %%
df = pd.concat([df1, df2], axis = 0)

# %%
df.sample(2)
# Out:
#      SubjectId  abdominalextensiondepthsitting  acromialheight  \
# 286      15015                             209            1378
# 97       10695                             295            1403
#
#      acromionradialelength  anklecircumference  axillaheight  \
# 286                    313                 212          1267
# 97                     327                 231          1291
#
#      balloffootcircumference  balloffootlength  biacromialbreadth  \
# 286                      243               193                346
# 97                       242               196                367
#
#      bicepscircumferenceflexed  ...          Branch  PrimaryMOS  \
# 286                        301  ...  Combat Support         90A
# 97                         348  ...     Combat Arms         19K
#
#      SubjectsBirthLocation  SubjectNumericRace  Ethnicity  DODRace  Age  \
# 286               New York                   1        NaN        1   37
# 97                Arkansas                   1        NaN        1   26
#
#      Heightin  Weightlbs  WritingPreference
# 286        67        140         Right hand
# 97         67        174         Right hand
#
# [2 rows x 108 columns]

# %% [markdown]
# ## Schema

# %%
schema = pd.read_csv('ANSUR II Databases Overview.csv')
schema.head()
# Out:
#                 feature                                        description  \
# 0             SubjectId  A unique number for each participant measured ...
# 1  SubjectBirthLocation  Subject Birth Location; a U.S. state or foreig...
# 2    SubjectNumericRace  Subject Numeric Race; a single or multi-digit ...
# 3             Ethnicity  self-reported ethnicity (verified through inte...
# 4               DODRace  Department of Defense Race; a single digit ind...
#
#                type
# 0  Demographic data
# 1  Demographic data
# 2  Demographic data
# 3  Demographic data
# 4  Demographic data

# %%
schema['feature'] = schema['feature'].str.strip()

# %%
def mapping(feature):
    '''
    Description:
    This function gets a column and map back its original description.
    
    INPUT:
    feature - (str) column name as a string
    
    OUTPUT:
    desc - (str) full description
    '''
    desc = list(schema[schema['feature'] == feature]['description'])
    return desc

# %%
mapping('DODRace')
# Out:
# ['Department of Defense Race; a single digit indicating a subject’s self-reported preferred single race where selecting multiple races is not an option. This variable is intended to be comparable to the Defense Manpower Data Center demographic data. Where 1 = White, 2 = Black, 3 = Hispanic, 4 = Asian, 5 = Native American, 6 = Pacific Islander, 8 = Other']

# %% [markdown]
# ## Dropping columns with too many nulls

# %%
cols = set(df.columns)

# %%
#to handle missing values drop any columns that exceeds the threshold value

threshold = 0.5 # 50%
df = df.loc[:, df.isna().mean().lt(threshold)]

# %%
# show dropped columns
dropped = cols ^ set(df.columns)
list(dropped)
# Out:
# ['Ethnicity']

# %% [markdown]
# ## Dropping redundant/irrelevant features

# %%
schema
# Out:
#                              feature  \
# 0                          SubjectId
# 1               SubjectBirthLocation
# 2                 SubjectNumericRace
# 3                          Ethnicity
# 4                            DODRace
# 5                             Gender
# 6                                Age
# 7                           Heightin
# 8                          Weightlbs
# 9                  WritingPreference
# 10                              Date
# 11                      Installation
# 12                         Component
# 13                           Branch
# 14                       PrimaryMOS
# 15                              NOTE
# 16   abdominalextensiondepthsitting
# 17                    acromialheight
# 18             acromionradialelength
# 19                anklecircumference
# 20                      axillaheight
# 21           balloffootcircumference
# 22                  balloffootlength
# 23                 biacromialbreadth
# 24         bicepscircumferenceflexed
# 25                  bicristalbreadth
# 26                  bideltoidbreadth
# 27                bimalleolarbreadth
# 28                  bitragionchinarc
# 29         bitragionsubmandibulararc
# 30                bizygomaticbreadth
# 31              buttockcircumference
# 32                      buttockdepth
# 33                     buttockheight
# 34                 buttockkneelength
# 35            buttockpopliteallength
# 36                 calfcircumference
# 37                   cervicaleheight
# 38                      chestbreadth
# 39                chestcircumference
# 40                        chestdepth
# 41                      chestheight
# 42                      crotchheight
# 43             crotchlengthomphalion
# 44    crotchlengthposterioromphalion
# 45                        earbreadth
# 46                         earlength
# 47                     earprotrusion
# 48                   elbowrestheight
# 49                  eyeheightsitting
# 50             footbreadthhorizontal
# 51                        footlength
# 52         forearmcenterofgriplength
# 53        forearmcircumferenceflexed
# 54             forearmforearmbreadth
# 55                 forearmhandlength
# 56               functionalleglength
# 57                       handbreadth
# 58                 handcircumference
# 59                        handlength
# 60                       headbreadth
# 61                 headcircumference
# 62                        headlength
# 63            heelanklecircumference
# 64                       heelbreadth
# 65                        hipbreadth
# 66                 hipbreadthsitting
# 67                iliocristaleheight
# 68             interpupillarybreadth
# 69                        interscyei
# 70                       interscyeii
# 71              kneeheightmidpatella
# 72                 kneeheightsitting
# 73    lateralfemoralepicondyleheight
# 74            lateralmalleolusheight
# 75           lowerthighcircumference
# 76               mentonsellionlength
# 77                 neckcircumference
# 78             neckcircumferencebase
# 79     overheadfingertipreachsitting
# 80                        palmlength
# 81                   poplitealheight
# 82              radialestylionlength
# 83             shouldercircumference
# 84               shoulderelbowlength
# 85                    shoulderlength
# 86                    sittingheight
# 87            sleevelengthspinewrist
# 88                     sleeveoutseam
# 89                              span
# 90                           stature
# 91               suprasternaleheight
# 92                    tenthribheight
# 93                thighcircumference
# 94                    thighclearance
# 95                     thumbtipreach
# 96                      tibialheight
# 97                  tragiontopofhead
# 98               trochanterionheight
# 99     verticaltrunkcircumferenceusa
# 100                  waistbacklength
# 101                     waistbreadth
# 102               waistcircumference
# 103                       waistdepth
# 104          waistfrontlengthsitting
# 105             waistheightomphalion
# 106                         weightkg
# 107              wristcircumference
# 108                      wristheight
# 109                              NaN
#
#                                            description                 type
# 0    A unique number for each participant measured ...     Demographic data
# 1    Subject Birth Location; a U.S. state or foreig...     Demographic data
# 2    Subject Numeric Race; a single or multi-digit ...     Demographic data
# 3    self-reported ethnicity (verified through inte...     Demographic data
# 4    Department of Defense Race; a single digit ind...     Demographic data
# 5                                   “Male” or “Female”     Demographic data
# 6                           Participant’s age in years     Demographic data
# 7    Height in Inches; self-reported, comparable to...     Demographic data
# 8    Weight in Pounds; self-reported, comparable to...     Demographic data
# 9    Writing Preference; “Right hand”, “Left hand”,...     Demographic data
# 10   Date the participant was measured, ranging fro...     Demographic data
# 11   U.S. Army installation where the measurement o...     Demographic data
# 12   “Army National Guard”, “Army Reserve”, or “Reg...     Demographic data
# 13   “Combat Arms”, “Combat Support”, or “Combat Se...     Demographic data
# 14             Primary Military Occupational Specialty     Demographic data
# 15   measurements are recorded in millimeters with ...         note to self
# 16                  Abdominal Extension Depth, Sitting  Anthropometric Data
# 17                                     Acromial Height  Anthropometric Data
# 18                             Acromion-Radiale Length  Anthropometric Data
# 19                                 Ankle Circumference  Anthropometric Data
# 20                                       Axilla Height  Anthropometric Data
# 21                          Ball of Foot Circumference  Anthropometric Data
# 22                                 Ball of Foot Length  Anthropometric Data
# 23                                  Biacromial Breadth  Anthropometric Data
# 24                        Biceps Circumference, Flexed  Anthropometric Data
# 25                                   Bicristal Breadth  Anthropometric Data
# 26                                   Bideltoid Breadth  Anthropometric Data
# 27                                 Bimalleolar Breadth  Anthropometric Data
# 28                                  Bitragion Chin Arc  Anthropometric Data
# 29                         Bitragion Submandibular Arc  Anthropometric Data
# 30                                 Bizygomatic Breadth  Anthropometric Data
# 31                               Buttock Circumference  Anthropometric Data
# 32                                       Buttock Depth  Anthropometric Data
# 33                                      Buttock Height  Anthropometric Data
# 34                                 Buttock-Knee Length  Anthropometric Data
# 35                            Buttock-Popliteal Length  Anthropometric Data
# 36                                  Calf Circumference  Anthropometric Data
# 37                                     Cervical Height  Anthropometric Data
# 38                                       Chest Breadth  Anthropometric Data
# 39                                 Chest Circumference  Anthropometric Data
# 40                                         Chest Depth  Anthropometric Data
# 41                                        Chest Height  Anthropometric Data
# 42                                       Crotch Height  Anthropometric Data
# 43                           Crotch Length (Omphalion)  Anthropometric Data
# 44                Crotch Length, Posterior (Omphalion)  Anthropometric Data
# 45                                         Ear Breadth  Anthropometric Data
# 46                                          Ear Length  Anthropometric Data
# 47                                      Ear Protrusion  Anthropometric Data
# 48                                   Elbow Rest Height  Anthropometric Data
# 49                                 Eye Height, Sitting  Anthropometric Data
# 50                            Foot Breadth, Horizontal  Anthropometric Data
# 51                                         Foot Length  Anthropometric Data
# 52                       Forearm-Center of Grip Length  Anthropometric Data
# 53                       Forearm Circumference, Flexed  Anthropometric Data
# 54                             Forearm-Forearm Breadth  Anthropometric Data
# 55                                Forearm -Hand Length  Anthropometric Data
# 56                               Functional Leg Length  Anthropometric Data
# 57                                        Hand Breadth  Anthropometric Data
# 58                                  Hand Circumference  Anthropometric Data
# 59                                         Hand Length  Anthropometric Data
# 60                                        Head Breadth  Anthropometric Data
# 61                                  Head Circumference  Anthropometric Data
# 62                                         Head Length  Anthropometric Data
# 63                            Heel-Ankle Circumference  Anthropometric Data
# 64                                        Heel Breadth  Anthropometric Data
# 65                                         Hip Breadth  Anthropometric Data
# 66                                Hip Breadth, Sitting  Anthropometric Data
# 67                                 Iliocristale Height  Anthropometric Data
# 68                              Interpupillary Breadth  Anthropometric Data
# 69                                         Interscye I  Anthropometric Data
# 70                                        Interscye II  Anthropometric Data
# 71                             Knee Height, Midpatella  Anthropometric Data
# 72                                Knee Height, Sitting  Anthropometric Data
# 73                   Lateral Femoral Epicondyle Height  Anthropometric Data
# 74                            Lateral Malleolus Height  Anthropometric Data
# 75                           Lower Thigh Circumference  Anthropometric Data
# 76                               Menton-Sellion Length  Anthropometric Data
# 77                                  Neck Circumference  Anthropometric Data
# 78                            Neck Circumference, Base  Anthropometric Data
# 79                   Overhead Fingertip Reach, Sitting  Anthropometric Data
# 80                                         Palm Length  Anthropometric Data
# 81                                    Popliteal Height  Anthropometric Data
# 82                              Radiale-Stylion Length  Anthropometric Data
# 83                              Shoulder Circumference  Anthropometric Data
# 84                               Shoulder-Elbow Length  Anthropometric Data
# 85                                     Shoulder Length  Anthropometric Data
# 86                                      Sitting Height  Anthropometric Data
# 87                          Sleeve Length: Spine-Wrist  Anthropometric Data
# 88                                      Sleeve Outseam  Anthropometric Data
# 89                                                Span  Anthropometric Data
# 90                                             Stature  Anthropometric Data
# 91                                Suprasternale Height  Anthropometric Data
# 92                                    Tenth Rib Height  Anthropometric Data
# 93                                 Thigh Circumference  Anthropometric Data
# 94                                     Thigh Clearance  Anthropometric Data
# 95                                      Thumbtip Reach  Anthropometric Data
# 96                                      Tibiale Height  Anthropometric Data
# 97                                 Tragion-Top of Head  Anthropometric Data
# 98                                Trochanterion Height  Anthropometric Data
# 99                  Vertical Trunk Circumference (USA)  Anthropometric Data
# 100                      Waist Back Length (Omphalion)  Anthropometric Data
# 101                                      Waist Breadth  Anthropometric Data
# 102                    Waist Circumference (Omphalion)  Anthropometric Data
# 103                                        Waist Depth  Anthropometric Data
# 104                        Waist Front Length, Sitting  Anthropometric Data
# 105                           Waist Height (Omphalion)  Anthropometric Data
# 106                                  Weight (in kg*10)  Anthropometric Data
# 107                                Wrist Circumference  Anthropometric Data
# 108                                       Wrist Height  Anthropometric Data
# 109                                                NaN                  NaN

# %%
df['SubjectsBirthLocation'].value_counts()
# Out:
# California                  446
# New York                    420
# Texas                       397
# Indiana                     266
# Oklahoma                    221
# Illinois                    216
# Florida                     210
# Minnesota                   200
# Michigan                    196
# Mississippi                 194
# Georgia                     170
# Alabama                     164
# South Carolina              161
# North Carolina              149
# Ohio                        142
# Louisiana                   137
# Pennsylvania                132
# Virginia                    118
# Massachusetts               112
# Wisconsin                   102
# Germany                      92
# New Jersey                   89
# Puerto Rico                  88
# Arizona                      84
# Missouri                     84
# Colorado                     81
# Maryland                     80
# Tennessee                    74
# Kentucky                     69
# Washington                   66
# Kansas                       63
# South Dakota                 56
# Iowa                         55
# Arkansas                     54
# Philippines                  46
# Oregon                       42
# Mexico                       39
# Connecticut                  36
# Jamaica                      35
# South Korea                  31
# Nebraska                     31
# Hawaii                       29
# Utah                         28
# West Virginia                26
# Nevada                       24
# Idaho                        20
# Rhode Island                 19
# District of Columbia         19
# North Dakota                 18
# Maine                        18
# Delaware                     17
# Dominican Republic           17
# New Mexico                   17
# New Hampshire                14
# Vermont                      13
# Vietnam                      13
# Colombia                     13
# Haiti                        12
# Montana                      12
# Japan                        11
# United Kingdom               11
# Panama                       10
# Guam                         10
# Guyana                        9
# Canada                        9
# Alaska                        8
# Russia                        8
# Peru                          8
# China                         8
# American Samoa                8
# Wyoming                       7
# US Virgin Islands             7
# Ukraine                       7
# Trinidad and Tobago           7
# India                         6
# Liberia                       6
# Ecuador                       5
# El Salvador                   5
# Poland                        5
# Barbados                      5
# Grenada                       4
# Honduras                      4
# Thailand                      4
# South Africa                  4
# Nigeria                       4
# Portugal                      4
# Nicaragua                     4
# Cuba                          4
# Romania                       3
# Israel                        3
# Laos                          3
# Belgium                       3
# Morocco                       3
# Kenya                         3
# France                        3
# Nepal                         3
# United States                 2
# Turkey                        2
# Sudan                         2
# Antigua and Barbuda           2
# Ghana                         2
# Netherlands                   2
# Belize                        2
# Taiwan                        2
# Italy                         2
# Iraq                          2
# Burma                         2
# Micronesia                    2
# Lebanon                       2
# Bolivia                       2
# Iceland                       2
# Sierra Leone                  2
# Costa Rica                    2
# Palau                         2
# Cameroon                      2
# Zambia                        1
# Paraguay                      1
# Serbia                        1
# Chile                         1
# Sri Lanka                     1
# Bulgaria                      1
# Korea                         1
# Saint Lucia                   1
# Bangladesh                    1
# Azerbaijan                    1
# Venezuela                     1
# Fiji                          1
# Northern Mariana Islands      1
# Iran                          1
# Bosnia and Herzegovina        1
# Bermuda                       1
# Dominica                      1
# Cambodia                      1
# Argentina                     1
# British Virgin Islands        1
# Guadalupe                     1
# Bahamas                       1
# Senegal                       1
# Brazil                        1
# Cape Verde                    1
# Syria                         1
# Singapore                     1
# French Guiana                 1
# Guatemala                     1
# Ethiopia                      1
# Egypt                         1
# Togo                          1
# Ivory Coast                   1
# Belarus                       1
# New Zealand                   1
# South America                 1
# Denmark                       1
# Name: SubjectsBirthLocation, dtype: int64

# %%
mapping('SubjectNumericRace')
# Out:
# ['Subject Numeric Race; a single or multi-digit code indicating a subject’s self-reported race or races (verified through interview). Where 1 = White, 2 = Black, 3 = Hispanic, 4 = Asian, 5 = Native American, 6 = Pacific Islander, 8 = Other']

# %%
pprint(mapping('DODRace'))
# Out:
# ['Department of Defense Race; a single digit indicating a subject’s '
#  'self-reported preferred single race where selecting multiple races is not an '
#  'option. This variable is intended to be comparable to the Defense Manpower '
#  'Data Center demographic data. Where 1 = White, 2 = Black, 3 = Hispanic, 4 = '
#  'Asian, 5 = Native American, 6 = Pacific Islander, 8 = Other']

# %%
mapping('Weightlbs')
# Out:
# ['Weight in Pounds; self-reported, comparable to measured “weightkg”']

# %%
mapping('Heightin')
# Out:
# ['Height in Inches; self-reported, comparable to measured “stature”']

# %%
mapping('PrimaryMOS')
# Out:
# ['Primary Military Occupational Specialty']

# %%
features_to_drop = [
    'SubjectId', # irrelavant
    'SubjectsBirthLocation', # irrelavant
    'SubjectNumericRace', # redundant
    'Heightin', # redundant
    'Weightlbs',  # redundant
    'Date',  # irrelavant
    'Installation',  # irrelavant
    'PrimaryMOS', # irrelavant
    # 'WritingPreference', # there are some studies about its association with race?
    ]

# %%
df = df.drop(features_to_drop, axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6068 entries, 0 to 1985
# Data columns (total 99 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   abdominalextensiondepthsitting  6068 non-null   int64
#  1   acromialheight                  6068 non-null   int64
#  2   acromionradialelength           6068 non-null   int64
#  3   anklecircumference              6068 non-null   int64
#  4   axillaheight                    6068 non-null   int64
#  5   balloffootcircumference         6068 non-null   int64
#  6   balloffootlength                6068 non-null   int64
#  7   biacromialbreadth               6068 non-null   int64
#  8   bicepscircumferenceflexed       6068 non-null   int64
#  9   bicristalbreadth                6068 non-null   int64
#  10  bideltoidbreadth                6068 non-null   int64
#  11  bimalleolarbreadth              6068 non-null   int64
#  12  bitragionchinarc                6068 non-null   int64
#  13  bitragionsubmandibulararc       6068 non-null   int64
#  14  bizygomaticbreadth              6068 non-null   int64
#  15  buttockcircumference            6068 non-null   int64
#  16  buttockdepth                    6068 non-null   int64
#  17  buttockheight                   6068 non-null   int64
#  18  buttockkneelength               6068 non-null   int64
#  19  buttockpopliteallength          6068 non-null   int64
#  20  calfcircumference               6068 non-null   int64
#  21  cervicaleheight                 6068 non-null   int64
#  22  chestbreadth                    6068 non-null   int64
#  23  chestcircumference              6068 non-null   int64
#  24  chestdepth                      6068 non-null   int64
#  25  chestheight                     6068 non-null   int64
#  26  crotchheight                    6068 non-null   int64
#  27  crotchlengthomphalion           6068 non-null   int64
#  28  crotchlengthposterioromphalion  6068 non-null   int64
#  29  earbreadth                      6068 non-null   int64
#  30  earlength                       6068 non-null   int64
#  31  earprotrusion                   6068 non-null   int64
#  32  elbowrestheight                 6068 non-null   int64
#  33  eyeheightsitting                6068 non-null   int64
#  34  footbreadthhorizontal           6068 non-null   int64
#  35  footlength                      6068 non-null   int64
#  36  forearmcenterofgriplength       6068 non-null   int64
#  37  forearmcircumferenceflexed      6068 non-null   int64
#  38  forearmforearmbreadth           6068 non-null   int64
#  39  forearmhandlength               6068 non-null   int64
#  40  functionalleglength             6068 non-null   int64
#  41  handbreadth                     6068 non-null   int64
#  42  handcircumference               6068 non-null   int64
#  43  handlength                      6068 non-null   int64
#  44  headbreadth                     6068 non-null   int64
#  45  headcircumference               6068 non-null   int64
#  46  headlength                      6068 non-null   int64
#  47  heelanklecircumference          6068 non-null   int64
#  48  heelbreadth                     6068 non-null   int64
#  49  hipbreadth                      6068 non-null   int64
#  50  hipbreadthsitting               6068 non-null   int64
#  51  iliocristaleheight              6068 non-null   int64
#  52  interpupillarybreadth           6068 non-null   int64
#  53  interscyei                      6068 non-null   int64
#  54  interscyeii                     6068 non-null   int64
#  55  kneeheightmidpatella            6068 non-null   int64
#  56  kneeheightsitting               6068 non-null   int64
#  57  lateralfemoralepicondyleheight  6068 non-null   int64
#  58  lateralmalleolusheight          6068 non-null   int64
#  59  lowerthighcircumference         6068 non-null   int64
#  60  mentonsellionlength             6068 non-null   int64
#  61  neckcircumference               6068 non-null   int64
#  62  neckcircumferencebase           6068 non-null   int64
#  63  overheadfingertipreachsitting   6068 non-null   int64
#  64  palmlength                      6068 non-null   int64
#  65  poplitealheight                 6068 non-null   int64
#  66  radialestylionlength            6068 non-null   int64
#  67  shouldercircumference           6068 non-null   int64
#  68  shoulderelbowlength             6068 non-null   int64
#  69  shoulderlength                  6068 non-null   int64
#  70  sittingheight                   6068 non-null   int64
#  71  sleevelengthspinewrist          6068 non-null   int64
#  72  sleeveoutseam                   6068 non-null   int64
#  73  span                            6068 non-null   int64
#  74  stature                         6068 non-null   int64
#  75  suprasternaleheight             6068 non-null   int64
#  76  tenthribheight                  6068 non-null   int64
#  77  thighcircumference              6068 non-null   int64
#  78  thighclearance                  6068 non-null   int64
#  79  thumbtipreach                   6068 non-null   int64
#  80  tibialheight                    6068 non-null   int64
#  81  tragiontopofhead                6068 non-null   int64
#  82  trochanterionheight             6068 non-null   int64
#  83  verticaltrunkcircumferenceusa   6068 non-null   int64
#  84  waistbacklength                 6068 non-null   int64
#  85  waistbreadth                    6068 non-null   int64
#  86  waistcircumference              6068 non-null   int64
#  87  waistdepth                      6068 non-null   int64
#  88  waistfrontlengthsitting         6068 non-null   int64
#  89  waistheightomphalion            6068 non-null   int64
#  90  weightkg                        6068 non-null   int64
#  91  wristcircumference              6068 non-null   int64
#  92  wristheight                     6068 non-null   int64
#  93  Gender                          6068 non-null   object
#  94  Component                       6068 non-null   object
#  95  Branch                          6068 non-null   object
#  96  DODRace                         6068 non-null   int64
#  97  Age                             6068 non-null   int64
#  98  WritingPreference               6068 non-null   object
# dtypes: int64(95), object(4)
# memory usage: 4.6+ MB

# %% [markdown]
# ## Explore Data

# %%
# checking for null values
df.isnull().sum().any()
# Out:
# False

# %%
# checking for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
df.describe().T
# Out:
#                                  count         mean         std     min  \
# abdominalextensiondepthsitting  6068.0   246.468688   37.400106   155.0
# acromialheight                  6068.0  1406.161338   79.091048  1115.0
# acromionradialelength           6068.0   327.374423   20.720018   249.0
# anklecircumference              6068.0   224.891397   16.051833   156.0
# axillaheight                    6068.0  1299.608767   72.022286  1038.0
# balloffootcircumference         6068.0   244.192650   16.845020   186.0
# balloffootlength                6068.0   194.754614   13.516368   151.0
# biacromialbreadth               6068.0   399.204186   30.236914   283.0
# bicepscircumferenceflexed       6068.0   340.934245   41.519866   216.0
# bicristalbreadth                6068.0   274.735003   19.221034   197.0
# bideltoidbreadth                6068.0   490.754450   42.135535   357.0
# bimalleolarbreadth              6068.0    72.252637    5.344590    55.0
# bitragionchinarc                6068.0   324.896506   17.087501   267.0
# bitragionsubmandibulararc       6068.0   306.636124   20.794166   245.0
# bizygomaticbreadth              6068.0   139.723467    7.308457   116.0
# buttockcircumference            6068.0  1020.084707   76.422643   737.0
# buttockdepth                    6068.0   241.619974   26.482986   168.0
# buttockheight                   6068.0   870.152274   54.822574   656.0
# weightkg                         682.00   785.0   896.00  1442.0
# wristcircumference               159.00   170.0   179.00   216.0
# wristheight                      797.00   830.0   863.00  1009.0
# DODRace                            1.00     1.0     2.00     8.0
# Age                               23.00    28.0    36.00    58.0

# %%
plt.figure(figsize=(22, 18))
sns.heatmap(df.corr(numeric_only=True), 
            vmin=-1,
            vmax= 1,
            cmap= 'GnBu', 
            linewidths=.12, 
            linecolor='white',
            fmt='.2g',
            square=True);

# %% [markdown]
# It's hard to visualuze the correlation since we have too many features

# %%
# show correlated features with 0.9 correlation scores
correlations = df.corr(numeric_only=True).unstack().sort_values()
highest_corr = correlations[correlations > 0.9]
highest_corr
# Out:
# chestheight                     kneeheightmidpatella              0.900121
# kneeheightmidpatella            chestheight                       0.900121
# hipbreadthsitting               buttockcircumference              0.900228
# buttockcircumference            hipbreadthsitting                 0.900228
# poplitealheight                 stature                           0.900976
# stature                         poplitealheight                   0.900976
# shouldercircumference           biacromialbreadth                 0.901051
# biacromialbreadth               shouldercircumference             0.901051
# poplitealheight                 suprasternaleheight               0.901304
# suprasternaleheight             poplitealheight                   0.901304
# poplitealheight                 tenthribheight                    0.901478
# tenthribheight                  poplitealheight                   0.901478
# wristcircumference              handcircumference                 0.901539
# handcircumference               wristcircumference                0.901539
# crotchheight                    acromialheight                    0.901554
# acromialheight                  crotchheight                      0.901554
# verticaltrunkcircumferenceusa   weightkg                          0.901707
# weightkg                        verticaltrunkcircumferenceusa     0.901707
# suprasternaleheight             kneeheightmidpatella              0.901805
# kneeheightmidpatella            suprasternaleheight               0.901805
# axillaheight                    trochanterionheight               0.902156
# trochanterionheight             axillaheight                      0.902156
# cervicaleheight                 functionalleglength               0.902260
# functionalleglength             cervicaleheight                   0.902260
# kneeheightmidpatella            cervicaleheight                   0.903019
# cervicaleheight                 kneeheightmidpatella              0.903019
# suprasternaleheight             functionalleglength               0.904056
# functionalleglength             suprasternaleheight               0.904056
# lateralfemoralepicondyleheight  poplitealheight                   0.904087
# poplitealheight                 lateralfemoralepicondyleheight    0.904087
# buttockheight                   kneeheightsitting                 0.904716
# kneeheightsitting               buttockheight                     0.904716
# axillaheight                    wristheight                       0.905063
# wristheight                     axillaheight                      0.905063
# sleeveoutseam                   sleevelengthspinewrist            0.905575
# sleevelengthspinewrist          sleeveoutseam                     0.905575
# lateralfemoralepicondyleheight  trochanterionheight               0.905602
# trochanterionheight             lateralfemoralepicondyleheight    0.905602
# axillaheight                    kneeheightmidpatella              0.905870
# kneeheightmidpatella            axillaheight                      0.905870
# lateralfemoralepicondyleheight  tenthribheight                    0.906050
# tenthribheight                  lateralfemoralepicondyleheight    0.906050
# tibialheight                    axillaheight                      0.906334
# axillaheight                    tibialheight                      0.906334
# weightkg                        bideltoidbreadth                  0.906600
# bideltoidbreadth                weightkg                          0.906600
# crotchheight                    chestheight                       0.906608
# chestheight                     crotchheight                      0.906608
# suprasternaleheight             crotchheight                      0.906959
# crotchheight                    suprasternaleheight               0.906959
# suprasternaleheight             span                              0.907156
# span                            suprasternaleheight               0.907156
# axillaheight                    poplitealheight                   0.907812
# poplitealheight                 axillaheight                      0.907812
# cervicaleheight                 span                              0.907938
# span                            cervicaleheight                   0.907938
# poplitealheight                 iliocristaleheight                0.908261
# iliocristaleheight              poplitealheight                   0.908261
# crotchheight                    cervicaleheight                   0.908512
# cervicaleheight                 crotchheight                      0.908512
# poplitealheight                 cervicaleheight                   0.908713
# cervicaleheight                 poplitealheight                   0.908713
# tibialheight                    buttockheight                     0.910002
# buttockheight                   tibialheight                      0.910002
# kneeheightsitting               functionalleglength               0.910524
# functionalleglength             kneeheightsitting                 0.910524
# poplitealheight                 chestheight                       0.910701
# chestheight                     poplitealheight                   0.910701
# iliocristaleheight              chestheight                       0.911225
# chestheight                     iliocristaleheight                0.911225
# forearmhandlength               sleeveoutseam                     0.911555
# sleeveoutseam                   forearmhandlength                 0.911555
# trochanterionheight             waistheightomphalion              0.911834
# waistheightomphalion            trochanterionheight               0.911834
# span                            radialestylionlength              0.911834
# radialestylionlength            span                              0.911834
# tibialheight                    waistheightomphalion              0.911842
# waistheightomphalion            tibialheight                      0.911842
# forearmhandlength               kneeheightsitting                 0.912883
# kneeheightsitting               forearmhandlength                 0.912883
# radialestylionlength            sleeveoutseam                     0.913076
# sleeveoutseam                   radialestylionlength              0.913076
# waistheightomphalion            kneeheightmidpatella              0.913434
# kneeheightmidpatella            waistheightomphalion              0.913434
# bicepscircumferenceflexed       forearmcircumferenceflexed        0.914446
# forearmcircumferenceflexed      bicepscircumferenceflexed         0.914446
# kneeheightsitting               span                              0.914465
# span                            kneeheightsitting                 0.914465
# weightkg                        chestcircumference                0.915535
# chestcircumference              weightkg                          0.915535
# tenthribheight                  tibialheight                      0.915655
# tibialheight                    tenthribheight                    0.915655
# kneeheightmidpatella            iliocristaleheight                0.915802
# iliocristaleheight              kneeheightmidpatella              0.915802
# poplitealheight                 tibialheight                      0.916924
# tibialheight                    poplitealheight                   0.916924
# hipbreadth                      hipbreadthsitting                 0.917297
# hipbreadthsitting               hipbreadth                        0.917297
# axillaheight                    crotchheight                      0.917346
# crotchheight                    axillaheight                      0.917346
# trochanterionheight             kneeheightsitting                 0.918502
# kneeheightsitting               trochanterionheight               0.918502
# trochanterionheight             tenthribheight                    0.919069
# tenthribheight                  trochanterionheight               0.919069
# kneeheightsitting               chestheight                       0.919409
# chestheight                     kneeheightsitting                 0.919409
# tibialheight                    iliocristaleheight                0.920054
# iliocristaleheight              tibialheight                      0.920054
# crotchheight                    lateralfemoralepicondyleheight    0.920085
# lateralfemoralepicondyleheight  crotchheight                      0.920085
# buttockheight                   kneeheightmidpatella              0.920354
# kneeheightmidpatella            buttockheight                     0.920354
# shoulderelbowlength             span                              0.920613
# span                            shoulderelbowlength               0.920613
# kneeheightmidpatella            tenthribheight                    0.921298
# tenthribheight                  kneeheightmidpatella              0.921298
# wristheight                     acromialheight                    0.922687
# acromialheight                  wristheight                       0.922687
# balloffootcircumference         footbreadthhorizontal             0.922796
# buttockcircumference            thighcircumference                0.938459
# thighcircumference              buttockcircumference              0.938459
# crotchheight                    waistheightomphalion              0.938560
# waistheightomphalion            crotchheight                      0.938560
# kneeheightmidpatella            crotchheight                      0.938844
# crotchheight                    kneeheightmidpatella              0.938844
# poplitealheight                 kneeheightsitting                 0.938892
# kneeheightsitting               poplitealheight                   0.938892
# crotchheight                    kneeheightsitting                 0.939148
# kneeheightsitting               crotchheight                      0.939148
# forearmhandlength               radialestylionlength              0.939210
# radialestylionlength            forearmhandlength                 0.939210
# waistcircumference              abdominalextensiondepthsitting    0.939899
# abdominalextensiondepthsitting  waistcircumference                0.939899
# suprasternaleheight             waistheightomphalion              0.940121
# waistheightomphalion            suprasternaleheight               0.940121
# cervicaleheight                 tenthribheight                    0.940961
# tenthribheight                  cervicaleheight                   0.940961
# trochanterionheight             crotchheight                      0.941151
# crotchheight                    trochanterionheight               0.941151
# sleeveoutseam                   acromionradialelength             0.941310
# acromionradialelength           sleeveoutseam                     0.941310
# waistheightomphalion            cervicaleheight                   0.941346
# cervicaleheight                 waistheightomphalion              0.941346
# kneeheightsitting               suprasternaleheight               0.942133
# suprasternaleheight             kneeheightsitting                 0.942133
# lateralfemoralepicondyleheight  kneeheightmidpatella              0.942481
# kneeheightmidpatella            lateralfemoralepicondyleheight    0.942481
# tenthribheight                  waistheightomphalion              0.942951
# waistheightomphalion            tenthribheight                    0.942951
#                                 iliocristaleheight                0.943458
# iliocristaleheight              waistheightomphalion              0.943458
#                                 kneeheightsitting                 0.943759
# kneeheightsitting               iliocristaleheight                0.943759
# shoulderelbowlength             sleeveoutseam                     0.944525
# sleeveoutseam                   shoulderelbowlength               0.944525
# suprasternaleheight             tenthribheight                    0.945372
# tenthribheight                  suprasternaleheight               0.945372
#                                 acromialheight                    0.946931
# acromialheight                  tenthribheight                    0.946931
# axillaheight                    iliocristaleheight                0.947847
# iliocristaleheight              axillaheight                      0.947847
# lateralfemoralepicondyleheight  tibialheight                      0.947929
# tibialheight                    lateralfemoralepicondyleheight    0.947929
# shouldercircumference           bideltoidbreadth                  0.948128
# bideltoidbreadth                shouldercircumference             0.948128
# axillaheight                    waistheightomphalion              0.948190
# waistheightomphalion            axillaheight                      0.948190
# buttockpopliteallength          buttockkneelength                 0.948300
# buttockkneelength               buttockpopliteallength            0.948300
# span                            forearmhandlength                 0.949756
# forearmhandlength               span                              0.949756
# tibialheight                    kneeheightsitting                 0.953788
# kneeheightsitting               tibialheight                      0.953788
# waistdepth                      waistcircumference                0.954448
# waistcircumference              waistdepth                        0.954448
# axillaheight                    tenthribheight                    0.955993
# tenthribheight                  axillaheight                      0.955993
# axillaheight                    chestheight                       0.957121
# chestheight                     axillaheight                      0.957121
# kneeheightmidpatella            kneeheightsitting                 0.957161
# kneeheightsitting               kneeheightmidpatella              0.957161
# waistdepth                      abdominalextensiondepthsitting    0.958932
# abdominalextensiondepthsitting  waistdepth                        0.958932
# interscyei                      interscyeii                       0.960009
# interscyeii                     interscyei                        0.960009
# chestheight                     acromialheight                    0.960106
# acromialheight                  chestheight                       0.960106
# footlength                      balloffootlength                  0.960238
# balloffootlength                footlength                        0.960238
# waistcircumference              waistbreadth                      0.961013
# waistbreadth                    waistcircumference                0.961013
# handcircumference               handbreadth                       0.963017
# handbreadth                     handcircumference                 0.963017
# forearmhandlength               forearmcenterofgriplength         0.963470
# forearmcenterofgriplength       forearmhandlength                 0.963470
# kneeheightmidpatella            tibialheight                      0.963570
# tibialheight                    kneeheightmidpatella              0.963570
# tenthribheight                  iliocristaleheight                0.964874
# iliocristaleheight              tenthribheight                    0.964874
# chestheight                     stature                           0.965629
# stature                         chestheight                       0.965629
# trochanterionheight             buttockheight                     0.966848
# buttockheight                   trochanterionheight               0.966848
# cervicaleheight                 chestheight                       0.968008
# chestheight                     cervicaleheight                   0.968008
#                                 suprasternaleheight               0.968019
# suprasternaleheight             chestheight                       0.968019
# acromionradialelength           shoulderelbowlength               0.968584
# shoulderelbowlength             acromionradialelength             0.968584
# neckcircumferencebase           neckcircumference                 0.969489
# neckcircumference               neckcircumferencebase             0.969489
# axillaheight                    stature                           0.975837
# stature                         axillaheight                      0.975837
# axillaheight                    cervicaleheight                   0.977075
# cervicaleheight                 axillaheight                      0.977075
# stature                         acromialheight                    0.980269
# acromialheight                  stature                           0.980269
# suprasternaleheight             axillaheight                      0.980930
# axillaheight                    suprasternaleheight               0.980930
# sittingheight                   eyeheightsitting                  0.981693
# eyeheightsitting                sittingheight                     0.981693
# cervicaleheight                 acromialheight                    0.984230
# acromialheight                  cervicaleheight                   0.984230
#                                 suprasternaleheight               0.985013
# suprasternaleheight             acromialheight                    0.985013
# acromialheight                  axillaheight                      0.987452
# axillaheight                    acromialheight                    0.987452
# suprasternaleheight             stature                           0.989213
# stature                         suprasternaleheight               0.989213
# suprasternaleheight             cervicaleheight                   0.989308
# cervicaleheight                 suprasternaleheight               0.989308
# stature                         cervicaleheight                   0.991196
# cervicaleheight                 stature                           0.991196
# abdominalextensiondepthsitting  abdominalextensiondepthsitting    1.000000
# heelanklecircumference          heelanklecircumference            1.000000
# wristheight                     wristheight                       1.000000
# chestheight                     chestheight                       1.000000
# crotchheight                    crotchheight                      1.000000
# crotchlengthomphalion           crotchlengthomphalion             1.000000
# crotchlengthposterioromphalion  crotchlengthposterioromphalion    1.000000
# earbreadth                      earbreadth                        1.000000
# earlength                       earlength                         1.000000
# earprotrusion                   earprotrusion                     1.000000
# elbowrestheight                 elbowrestheight                   1.000000
# eyeheightsitting                eyeheightsitting                  1.000000
# footbreadthhorizontal           footbreadthhorizontal             1.000000
# footlength                      footlength                        1.000000
# forearmcenterofgriplength       forearmcenterofgriplength         1.000000
# forearmcircumferenceflexed      forearmcircumferenceflexed        1.000000
# forearmforearmbreadth           forearmforearmbreadth             1.000000
# forearmhandlength               forearmhandlength                 1.000000
# functionalleglength             functionalleglength               1.000000
# handbreadth                     handbreadth                       1.000000
# handcircumference               handcircumference                 1.000000
# handlength                      handlength                        1.000000
# chestdepth                      chestdepth                        1.000000
# chestcircumference              chestcircumference                1.000000
# chestbreadth                    chestbreadth                      1.000000
# cervicaleheight                 cervicaleheight                   1.000000
# acromialheight                  acromialheight                    1.000000
# acromionradialelength           acromionradialelength             1.000000
# anklecircumference              anklecircumference                1.000000
# axillaheight                    axillaheight                      1.000000
# balloffootcircumference         balloffootcircumference           1.000000
# balloffootlength                balloffootlength                  1.000000
# biacromialbreadth               biacromialbreadth                 1.000000
# bicepscircumferenceflexed       bicepscircumferenceflexed         1.000000
# bicristalbreadth                bicristalbreadth                  1.000000
# headbreadth                     headbreadth                       1.000000
# bideltoidbreadth                bideltoidbreadth                  1.000000
# bitragionchinarc                bitragionchinarc                  1.000000
# bitragionsubmandibulararc       bitragionsubmandibulararc         1.000000
# bizygomaticbreadth              bizygomaticbreadth                1.000000
# buttockcircumference            buttockcircumference              1.000000
# buttockdepth                    buttockdepth                      1.000000
# buttockheight                   buttockheight                     1.000000
# buttockkneelength               buttockkneelength                 1.000000
# buttockpopliteallength          buttockpopliteallength            1.000000
# calfcircumference               calfcircumference                 1.000000
# bimalleolarbreadth              bimalleolarbreadth                1.000000
# DODRace                         DODRace                           1.000000
# headcircumference               headcircumference                 1.000000
# heelbreadth                     heelbreadth                       1.000000
# span                            span                              1.000000
# stature                         stature                           1.000000
# suprasternaleheight             suprasternaleheight               1.000000
# tenthribheight                  tenthribheight                    1.000000
# thighcircumference              thighcircumference                1.000000
# thighclearance                  thighclearance                    1.000000
# thumbtipreach                   thumbtipreach                     1.000000
# tibialheight                    tibialheight                      1.000000
# tragiontopofhead                tragiontopofhead                  1.000000
# trochanterionheight             trochanterionheight               1.000000
# verticaltrunkcircumferenceusa   verticaltrunkcircumferenceusa     1.000000
# waistbacklength                 waistbacklength                   1.000000
# waistbreadth                    waistbreadth                      1.000000
# waistcircumference              waistcircumference                1.000000
# waistdepth                      waistdepth                        1.000000
# waistfrontlengthsitting         waistfrontlengthsitting           1.000000
# waistheightomphalion            waistheightomphalion              1.000000
# weightkg                        weightkg                          1.000000
# wristcircumference              wristcircumference                1.000000
# sleeveoutseam                   sleeveoutseam                     1.000000
# sleevelengthspinewrist          sleevelengthspinewrist            1.000000
# sittingheight                   sittingheight                     1.000000
# shoulderlength                  shoulderlength                    1.000000
# hipbreadth                      hipbreadth                        1.000000
# hipbreadthsitting               hipbreadthsitting                 1.000000
# iliocristaleheight              iliocristaleheight                1.000000
# interpupillarybreadth           interpupillarybreadth             1.000000
# interscyei                      interscyei                        1.000000
# interscyeii                     interscyeii                       1.000000
# kneeheightmidpatella            kneeheightmidpatella              1.000000
# kneeheightsitting               kneeheightsitting                 1.000000
# lateralfemoralepicondyleheight  lateralfemoralepicondyleheight    1.000000
# headlength                      headlength                        1.000000
# lateralmalleolusheight          lateralmalleolusheight            1.000000
# mentonsellionlength             mentonsellionlength               1.000000
# neckcircumference               neckcircumference                 1.000000
# neckcircumferencebase           neckcircumferencebase             1.000000
# overheadfingertipreachsitting   overheadfingertipreachsitting     1.000000
# palmlength                      palmlength                        1.000000
# poplitealheight                 poplitealheight                   1.000000
# radialestylionlength            radialestylionlength              1.000000
# shouldercircumference           shouldercircumference             1.000000
# shoulderelbowlength             shoulderelbowlength               1.000000
# lowerthighcircumference         lowerthighcircumference           1.000000
# Age                             Age                               1.000000
# dtype: float64

# %%
mapping('DODRace')
# Out:
# ['Department of Defense Race; a single digit indicating a subject’s self-reported preferred single race where selecting multiple races is not an option. This variable is intended to be comparable to the Defense Manpower Data Center demographic data. Where 1 = White, 2 = Black, 3 = Hispanic, 4 = Asian, 5 = Native American, 6 = Pacific Islander, 8 = Other']

# %%
df['DODRace'] = df['DODRace'].map({
1:'White', 2:'Black', 3:'Hispanic',
4:'Asian', 5:'Native American', 
6:'Pacific Islander', 8:'Other'})

# %%
value_counts = df['DODRace'].value_counts()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='DODRace', hue='Gender', saturation=1, edgecolor='k',
              linewidth=2, palette='viridis')
plt.title(f'Distribution of Race based on Gender')
plt.xlabel('Race')
plt.ylabel('Count')
plt.legend(title='Gender')
plt.show()

# %%
plt.figure(figsize=(14, 9))
sns.countplot(data=df, x='Age', hue='Gender', saturation=1, edgecolor='k',
              linewidth=2, palette='viridis')
plt.title(f'Distribution of Age based on Gender')
plt.xlabel('Age')
plt.ylabel('Count')
plt.legend(title='Gender')
plt.show()

# %%
# visualizing our target distribution
plt.figure(figsize=(8, 5))
sns.barplot(x=value_counts.index, y=value_counts.values,
            saturation=1, edgecolor='k',
            linewidth=2, palette='viridis')
plt.xticks(rotation=45)
plt.title(f'Target Classes')
plt.show()

# %%
value_counts = df['DODRace'].value_counts()

# classes with count of 500 or more
race_classes = list(value_counts[value_counts >= 500].index)
race_classes
# Out:
# ['White', 'Black', 'Hispanic']

# %%
# keep rows that has one of the 3 classes
df = df[df['DODRace'].isin(race_classes)]
df.shape
# Out:
# (5769, 99)

# %% [markdown]
# # DATA Preprocessing
# - In this step we divide our data to X(Features) and y(Target) then ,
# - To train and evaluation purposes we create train and test sets,
# - Lastly, scale our data if features not in same scale. Why?

# %% [markdown]
# ### Data harmonization
# must check for consistent units of Measurement

# %%
mapping('NOTE')
# Out:
# ['measurements are recorded in millimeters with the exception of the variable “weightkg”.']

# %%
subset = df.describe().T
subset = subset[['std', 'mean', 'max', 'min']]
subset
# Out:
#                                        std         mean     max     min
# abdominalextensiondepthsitting   37.457748   247.254290   451.0   155.0
# acromialheight                   78.303123  1408.630265  1683.0  1146.0
# acromionradialelength            20.444554   328.071590   393.0   249.0
# anklecircumference               15.965783   225.201768   293.0   156.0
# axillaheight                     71.260913  1301.902583  1553.0  1062.0
# balloffootcircumference          16.803556   244.408043   306.0   186.0
# balloffootlength                 13.379000   195.118911   245.0   151.0
# biacromialbreadth                30.124094   399.706015   489.0   283.0
# bicepscircumferenceflexed        41.270615   341.663027   490.0   216.0
# bicristalbreadth                 19.239580   274.903449   362.0   197.0
# bideltoidbreadth                 42.011888   491.454845   637.0   357.0
# bimalleolarbreadth                5.326965    72.335413    91.0    55.0
# bitragionchinarc                 17.050426   324.962212   385.0   267.0
# bitragionsubmandibulararc        20.818789   306.677760   390.0   245.0
# bizygomaticbreadth                7.248670   139.529381   166.0   116.0
# buttockcircumference             75.952953  1022.059456  1341.0   737.0
# sleevelengthspinewrist           56.904175   868.361068  1058.0   636.0
# sleeveoutseam                    37.905418   578.013001   709.0   410.0
# span                            109.925336  1766.951118  2121.0  1323.0
# stature                          89.256478  1716.938984  1993.0  1442.0
# suprasternaleheight              78.008905  1405.392442  1650.0  1150.0
# tenthribheight                   59.786688  1101.631479  1305.0   874.0
# thighcircumference               57.529947   623.583637   870.0   412.0
# thighclearance                   16.124405   176.696481   259.0   121.0
# thumbtipreach                    53.486543   791.044548   998.0   602.0
# tibialheight                     29.274797   459.389149   584.0   347.0
# tragiontopofhead                  6.635641   129.580343   150.0   105.0
# trochanterionheight              53.766243   884.659386  1095.0   660.0
# verticaltrunkcircumferenceusa    98.204399  1632.470966  1991.0  1342.0
# waistbacklength                  36.706353   460.990293   598.0   345.0
# waistbreadth                     36.395675   318.409950   461.0   211.0
# waistcircumference              114.386464   916.817126  1379.0   611.0
# waistdepth                       35.691681   230.459178   406.0   138.0
# waistfrontlengthsitting          31.714316   377.352054   494.0   289.0
# waistheightomphalion             61.957938  1033.591090  1245.0   808.0
# weightkg                        155.990338   800.981106  1442.0   358.0
# wristcircumference               13.060900   169.308372   216.0   124.0
# wristheight                      47.321580   831.334547  1009.0   688.0
# Age                               8.706610    29.776391    58.0    17.0

# %%
mapping('weightkg')
# Out:
# ['Weight (in kg*10)']

# %%
#df['weightkg'] = df['weightkg'] / 10

# %% [markdown]
# ### Column Transformer

# %%
cat_columns = list(df.select_dtypes(include=['object']).columns)
cat_columns.remove('DODRace')

# %%
cat_columns
# Out:
# ['Gender', 'Component', 'Branch', 'WritingPreference']

# %%
column_trans = make_column_transformer((
               OneHotEncoder( handle_unknown='ignore',
                              sparse_output=False), 
                              cat_columns),
                              remainder = 'passthrough')

# %% [markdown]
# ### Data Splitting

# %%
# splitting X and y
X = df.drop(columns = ['DODRace'])
y = df['DODRace']

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, stratify=y, random_state=14)

# %%
X_train.shape
# Out:
# (4615, 98)

# %%
X_test.shape
# Out:
# (1154, 98)

# %%
# our scaller 
sc = MinMaxScaler()

# %% [markdown]
# # Modelling
# - Fit the model with train dataset
# - Get predict from vanilla model on both train and test sets to examine if there is over/underfitting
# - Apply GridseachCV for both hyperparemeter tuning and sanity test of our model.
# - Use hyperparameters that you find from gridsearch and make final prediction and evaluate the result according to chosen metric.

# %% [markdown]
# ### Evaluation metric

# %%
def eval_metric(model, X_train, y_train, X_test, y_test):
    """ to get the metrics for the model """

    y_train_pred = model.predict(X_train)
    y_pred = model.predict(X_test)

    print("Train_Set")
    print(confusion_matrix(y_train, y_train_pred))
    print(classification_report(y_train, y_train_pred))
    print()
    print("Test_Set")
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))

# %% [markdown]
# ### Costum Scorrer

# %%
def recall_scorer():

# %% [markdown]
# ## 1. Logistic model

# %% [markdown]
# ### Vanilla Logistic Model

# %%
# Linear regression model
lr = LogisticRegression()

lr_pipe = make_pipeline(column_trans, sc, lr)

lr_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['Gender', 'Component',
#                                                    'Branch',
#                                                    'WritingPreference'])])),
#                 ('minmaxscaler', MinMaxScaler()),
#                 ('logisticregression', LogisticRegression())])

# %%
eval_metric(lr_pipe, X_train, y_train, X_test, y_test)
# Out:
# Train_Set
# [[ 950   16   72]
#  [  53  178  312]
#  [  32   57 2945]]
#               precision    recall  f1-score   support
#
#        Black       0.92      0.92      0.92      1038
#     Hispanic       0.71      0.33      0.45       543
#        White       0.88      0.97      0.93      3034
#
#     accuracy                           0.88      4615
#    macro avg       0.84      0.74      0.76      4615
# weighted avg       0.87      0.88      0.87      4615
#
#
# Test_Set
# [[222   6  32]
#  [ 17  38  81]
#  [ 15  15 728]]
#               precision    recall  f1-score   support
#
#        Black       0.87      0.85      0.86       260
#     Hispanic       0.64      0.28      0.39       136
#        White       0.87      0.96      0.91       758
#
#     accuracy                           0.86      1154
#    macro avg       0.79      0.70      0.72      1154
# weighted avg       0.84      0.86      0.84      1154

# %%
scores = cross_validate(lr_pipe,
                        X_train,
                        y_train,
                        scoring=['accuracy','f1_macro','precision_macro','recall_macro'],
                        cv = 10,
                        n_jobs=-1,
                        return_train_score=True)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_accuracy            0.873450
# train_accuracy           0.882051
# test_f1_macro            0.747015
# train_f1_macro           0.763314
# test_precision_macro     0.815107
# train_precision_macro    0.837179
# test_recall_macro        0.724883
# train_recall_macro       0.737608
# dtype: float64

# %% [markdown]
# ### Logistic Model GridsearchCV

# %%
lr_pipe.get_params()
# Out:
# {'memory': None,
#  'steps': [('columntransformer',
#    ColumnTransformer(remainder='passthrough',
#                      transformers=[('onehotencoder',
#                                     OneHotEncoder(handle_unknown='ignore',
#                                                   sparse_output=False),
#                                     ['Gender', 'Component', 'Branch',
#                                      'WritingPreference'])])),
#   ('minmaxscaler', MinMaxScaler()),
#   ('logisticregression', LogisticRegression())],
#  'verbose': False,
#  'columntransformer': ColumnTransformer(remainder='passthrough',
#                    transformers=[('onehotencoder',
#                                   OneHotEncoder(handle_unknown='ignore',
#                                                 sparse_output=False),
#                                   ['Gender', 'Component', 'Branch',
#                                    'WritingPreference'])]),
#  'minmaxscaler': MinMaxScaler(),
#  'logisticregression': LogisticRegression(),
#  'columntransformer__n_jobs': None,
#  'columntransformer__remainder': 'passthrough',
#  'columntransformer__sparse_threshold': 0.3,
#  'columntransformer__transformer_weights': None,
#  'columntransformer__transformers': [('onehotencoder',
#    OneHotEncoder(handle_unknown='ignore', sparse_output=False),
#    ['Gender', 'Component', 'Branch', 'WritingPreference'])],
#  'columntransformer__verbose': False,
#  'columntransformer__verbose_feature_names_out': True,
#  'columntransformer__onehotencoder': OneHotEncoder(handle_unknown='ignore', sparse_output=False),
#  'columntransformer__onehotencoder__categories': 'auto',
#  'columntransformer__onehotencoder__drop': None,
#  'columntransformer__onehotencoder__dtype': numpy.float64,
#  'columntransformer__onehotencoder__feature_name_combiner': 'concat',
#  'columntransformer__onehotencoder__handle_unknown': 'ignore',
#  'columntransformer__onehotencoder__max_categories': None,
#  'columntransformer__onehotencoder__min_frequency': None,
#  'columntransformer__onehotencoder__sparse': 'deprecated',
#  'columntransformer__onehotencoder__sparse_output': False,
#  'minmaxscaler__clip': False,
#  'minmaxscaler__copy': True,
#  'minmaxscaler__feature_range': (0, 1),
#  'logisticregression__C': 1.0,
#  'logisticregression__class_weight': None,
#  'logisticregression__dual': False,
#  'logisticregression__fit_intercept': True,
#  'logisticregression__intercept_scaling': 1,
#  'logisticregression__l1_ratio': None,
#  'logisticregression__max_iter': 100,
#  'logisticregression__multi_class': 'auto',
#  'logisticregression__n_jobs': None,
#  'logisticregression__penalty': 'l2',
#  'logisticregression__random_state': None,
#  'logisticregression__solver': 'lbfgs',
#  'logisticregression__tol': 0.0001,
#  'logisticregression__verbose': 0,
#  'logisticregression__warm_start': False}

# %%
lr_param_grid = {'logisticregression__C': [0.001, 0.01, 0.1, 1],
              'logisticregression__class_weight': ['balanced', {'White':1,'Hispanic':3.5,'Black':2}, 
              {'White':1,'Hispanic':4,'Black':2.5}, {'White':1,'Hispanic':4.5,'Black':3}],
              'logisticregression__penalty': ['l2', None],
              # from docs : For multiclass problems, only ‘newton-cg’, ‘sag’, ‘saga’ and ‘lbfgs’ handle multinomial loss;
              'logisticregression__solver': ['newton-cg', 'sag', 'saga', 'lbfgs'],
              }

# %% [markdown]
# Warning
#
# The choice of the algorithm depends on the penalty chosen. Supported penalties by solver:
#
# - ‘lbfgs’ - [‘l2’, None]
#
# - ‘liblinear’ - [‘l1’, ‘l2’]
#
# - ‘newton-cg’ - [‘l2’, None]
#
# - ‘newton-cholesky’ - [‘l2’, None]
#
# - ‘sag’ - [‘l2’, None]
#
# - ‘saga’ - [‘elasticnet’, ‘l1’, ‘l2’, None]

# %%
lr_model_grid = GridSearchCV(lr_pipe,
                              lr_param_grid ,
                              scoring="precision",
                              cv=10,
                              n_jobs=-1,
                              return_train_score=True)
lr_model_grid.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\arwao\Desktop\ML-bootcamp\Race Prediction\soldier_race_project_students.ipynb Cell 79 line 7
#       <a href='vscode-notebook-cell:/c%3A/Users/arwao/Desktop/ML-bootcamp/Race%20Prediction/soldier_race_project_students.ipynb#Y266sZmlsZQ%3D%3D?line=0'>1</a> lr_model_grid = GridSearchCV(lr_pipe,
#       <a href='vscode-notebook-cell:/c%3A/Users/arwao/Desktop/ML-bootcamp/Race%20Prediction/soldier_race_project_students.ipynb#Y266sZmlsZQ%3D%3D?line=1'>2</a>                               lr_param_grid ,
#       <a href='vscode-notebook-cell:/c%3A/Users/arwao/Desktop/ML-bootcamp/Race%20Prediction/soldier_race_project_students.ipynb#Y266sZmlsZQ%3D%3D?line=2'>3</a>                               scoring="recall",
#       <a href='vscode-notebook-cell:/c%3A/Users/arwao/Desktop/ML-bootcamp/Race%20Prediction/soldier_race_project_students.ipynb#Y266sZmlsZQ%3D%3D?line=3'>4</a>                               cv=10,
#       <a href='vscode-notebook-cell:/c%3A/Users/arwao/Desktop/ML-bootcamp/Race%20Prediction/soldier_race_project_students.ipynb#Y266sZmlsZQ%3D%3D?line=4'>5</a>                               n_jobs=-1,
#       <a href='vscode-notebook-cell:/c%3A/Users/arwao/Desktop/ML-bootcamp/Race%20Prediction/soldier_race_project_students.ipynb#Y266sZmlsZQ%3D%3D?line=5'>6</a>                               return_train_score=True)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/arwao/Desktop/ML-bootcamp/Race%20Prediction/soldier_race_project_students.ipynb#Y266sZmlsZQ%3D%3D?line=6'>7</a> lr_model_grid.fit(X_train, y_train)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\model_selection\_search.py:936, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     934 refit_start_time = time.time()
#     935 if y is not None:
# --> 936     self.best_estimator_.fit(X, y, **fit_params)
#     937 else:
#     938     self.best_estimator_.fit(X, **fit_params)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\pipeline.py:427, in Pipeline.fit(self, X, y, **fit_params)
#     425     if self._final_estimator != "passthrough":
#     426         fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 427         self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     429 return self
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\linear_model\_logistic.py:1169, in LogisticRegression.fit(self, X, y, sample_weight)
#    1139 @_fit_context(prefer_skip_nested_validation=True)
#    1140 def fit(self, X, y, sample_weight=None):
#    1141     """
#    1142     Fit the model according to the given training data.
#    1143
#    (...)
#    1167     The SAGA solver supports both float64 and float32 bit arrays.
#    1168     """
# -> 1169     solver = _check_solver(self.solver, self.penalty, self.dual)
#    1171     if self.penalty != "elasticnet" and self.l1_ratio is not None:
#    1172         warnings.warn(
#    1173             "l1_ratio parameter is only used when penalty is "
#    1174             "'elasticnet'. Got "
#    1175             "(penalty={})".format(self.penalty)
#    1176         )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\linear_model\_logistic.py:56, in _check_solver(solver, penalty, dual)
#      53 def _check_solver(solver, penalty, dual):
#      54     # TODO(1.4): Remove "none" option
#      55     if solver not in ["liblinear", "saga"] and penalty not in ("l2", "none", None):
# ---> 56         raise ValueError(
#      57             "Solver %s supports only 'l2' or 'none' penalties, got %s penalty."
#      58             % (solver, penalty)
#      59         )
#      60     if solver != "liblinear" and dual:
#      61         raise ValueError(
#      62             "Solver %s supports only dual=False, got dual=%s" % (solver, dual)
#      63         )
#
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got l1 penalty.

# %%
lr_model_grid = GridSearchCV(lr_pipe,
                              lr_param_grid ,
                              scoring="balanced_accuracy",
                              cv=10,
                              n_jobs=-1,
                              return_train_score=True)
lr_model_grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('columntransformer',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('onehotencoder',
#                                                                          OneHotEncoder(handle_unknown='ignore',
#                                                                                        sparse_output=False),
#                                                                          ['Gender',
#                                                                           'Component',
#                                                                           'Branch',
#                                                                           'WritingPreference'])])),
#                                        ('minmaxscaler', MinMaxScaler()),
#                                        ('logisticregression',
#                                         LogisticRegression())]),
#              n_jobs=-1,
#              param_gr...
#                          'logisticregression__class_weight': [{'Black': 2,
#                                                                'Hispanic': 3.5,
#                                                                'White': 1},
#                                                               {'Black': 2.5,
#                                                                'Hispanic': 4,
#                                                                'White': 1},
#                                                               {'Black': 3,
#                                                                'Hispanic': 4.5,
#                                                                'White': 1}],
#                          'logisticregression__multi_class': ['auto', 'ovr',
#                                                              'multinomial'],
#                          'logisticregression__penalty': ['l2', None],
#                          'logisticregression__solver': ['newton-cg', 'sag',
#                                                         'saga', 'lbfgs']},
#              return_train_score=True, scoring='balanced_accuracy')

# %%
lr_model_grid.best_estimator_
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['Gender', 'Component',
#                                                    'Branch',
#                                                    'WritingPreference'])])),
#                 ('minmaxscaler', MinMaxScaler()),
#                 ('logisticregression',
#                  LogisticRegression(C=1,
#                                     class_weight={'Black': 2, 'Hispanic': 3.5,
#                                                   'White': 1},
#                                     multi_class='multinomial', solver='sag'))])

# %%
eval_metric(lr_model_grid, X_train, y_train, X_test, y_test)
# Out:
# Train_Set
# [[ 949   54   35]
#  [  43  345  155]
#  [  40  325 2669]]
#               precision    recall  f1-score   support
#
#        Black       0.92      0.91      0.92      1038
#     Hispanic       0.48      0.64      0.54       543
#        White       0.93      0.88      0.91      3034
#
#     accuracy                           0.86      4615
#    macro avg       0.78      0.81      0.79      4615
# weighted avg       0.88      0.86      0.87      4615
#
#
# Test_Set
# [[226  20  14]
#  [ 17  78  41]
#  [ 15  78 665]]
#               precision    recall  f1-score   support
#
#        Black       0.88      0.87      0.87       260
#     Hispanic       0.44      0.57      0.50       136
#        White       0.92      0.88      0.90       758
#
#     accuracy                           0.84      1154
#    macro avg       0.75      0.77      0.76      1154
# weighted avg       0.86      0.84      0.85      1154

# %%
scores = cross_validate(lr_model_grid,
                        X_train,
                        y_train,
                        scoring=['accuracy','f1_macro','precision_macro','recall_macro'],
                        cv = 10,
                        n_jobs=-1,
                        return_train_score=True)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]

# %% [markdown]
# ## 2. SVC

# %% [markdown]
# ### Vanilla SVC model

# %% [markdown]
# ###  SVC Model GridsearchCV

# %% [markdown]
# ## 3. RF

# %% [markdown]
# ### Vanilla RF Model

# %% [markdown]
# ### RF Model GridsearchCV

# %% [markdown]
# ## 4. XGBoost

# %% [markdown]
# ### Vanilla XGBoost Model

# %% [markdown]
# ### XGBoost Model GridsearchCV

# %% [markdown]
# ---
# ---

# %% [markdown]
# ---
# ---

# %% [markdown]
# # SMOTE
# https://machinelearningmastery.com/smote-oversampling-for-imbalanced-classification/

# %% [markdown]
# ##  Smote implement

# %%
# !pip install imblearn

# %%
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline

# %% [markdown]
# ## Logistic Regression Over/ Under Sampling

# %% [markdown]
# ## Other Evaluation Metrics for Multiclass Classification

# %% [markdown]
# - Evaluation metrics
# https://towardsdatascience.com/comprehensive-guide-on-multiclass-classification-metrics-af94cfb83fbd

# %%
from sklearn.metrics import matthews_corrcoef
matthews_corrcoef?
matthews_corrcoef(y_test, y_pred)
# Out:
# 0.7380728719663084

# %%
from sklearn.metrics import cohen_kappa_score
cohen_kappa_score?
cohen_kappa_score(y_test, y_pred)
# Out:
# 0.7376215262514891

# %% [markdown]
# # Before the Deployment
# - Choose the model that works best based on your chosen metric
# - For final step, fit the best model with whole dataset to get better performance.
# - And your model ready to deploy, dump your model and scaler.

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
